# %%
import pandas as pd

# %%
dataframe=pd.read_csv("NISPUF17.csv",index_col=0)
dataframe.columns=[x.lower().strip() for x in dataframe.columns]
averageLessThan12=0
averageAt12=0
averageMoreThan12NoCollege=0
averageMoreThan12YesCollege=0
dataframeAverageLessThan12=dataframe[dataframe["educ1"]==1]
dataframeAverageAt12=dataframe[dataframe["educ1"]==2]
dataframeAverageMoreThan12NoCollege=dataframe[dataframe["educ1"]==3]
dataframeAverageMoreThan12YesCollege=dataframe[dataframe["educ1"]==4]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\405334398.py in <module>
# ----> 1 dataframe=pd.read_csv("NISPUF17.csv",index_col=0)
#       2 dataframe.columns=[x.lower().strip() for x in dataframe.columns]
#       3 averageLessThan12=0
#       4 averageAt12=0
#       5 averageMoreThan12NoCollege=0
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
countLessThan12=len(dataframeAverageLessThan12)
countLessThan12

# %%
dataframeAverageLessThan12

# %%
dataframeAverageLessThan12["educ1"].iloc[0]

# %%
for i in range(0,countLessThan12,1):
    averageLessThan12=averageLessThan12+dataframeAverageLessThan12["educ1"].iloc[i]
averageLessThan12=averageLessThan12/countLessThan12
averageLessThan12

# %%
import pandas as pd
dataframe=pd.read_csv("assets/NISPUF17.csv",index_col=0)
dataframe.columns=[x.lower().strip() for x in dataframe.columns]
dataframeBreastFedAndVaccine=dataframe[(dataframe["cbf_01"]==1) & (dataframe["p_numflu"]>0)]
series=dataframeBreastFedAndVaccine["p_numflu"]
lenght=len(series)
sum1=sum(series)
print(sum1/lenght)

# %%
import pandas as pd
dataframe=pd.read_csv("NISPUF17.csv")
dataframe=dataframe.set_index("SEX")
dataframe.columns=[x.lower().strip() for x in dataframe.columns]
    
dataframeVaccinePox=dataframe[(dataframe["had_cpox"]==1) & (dataframe["p_numvrc"]>0)]
dataframeVaccinePox

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd
sampleDataFrame=pd.read_csv("assets/NISPUF17.csv",index_col=0)
sampleDataFrame.columns=[x.lower().strip() for x in sampleDataFrame.columns]
# this is just an example dataframe
df=sampleDataFrame[((sampleDataFrame["had_cpox"]==1) | (sampleDataFrame["had_cpox"]==2)) & ((sampleDataFrame["p_numvrc"]==1) | (sampleDataFrame["p_numvrc"]==2) | (sampleDataFrame["p_numvrc"]==3) | (sampleDataFrame["p_numvrc"]==4) | (sampleDataFrame["p_numvrc"]==5))]
len(df)

# %%
def average_influenza_doses():
    # YOUR CODE HERE
    
    import pandas as pd
    import numpy as np
    mb = pd.read_csv("assets/NISPUF17.csv")
    gp1 = mb[mb['CBF_01'] == 1]
    gp2 = mb[mb['CBF_01'] == 2]
    print(np.mean(gp1['P_NUMFLU']), np.mean(gp2['P_NUMFLU']))
    return np.mean(gp1['P_NUMFLU']), np.mean(gp2['P_NUMFLU'])
    #raise NotImplementedError()

# %%
assert len(average_influenza_doses())==2, "Return two values in a tuple, the first for yes and the second for no."

# %%
dataframe=pd.read_excel("assets/Energy Indicators.xls")
Energy=dataframe[18:245]

# %%
Energy=Energy.drop(Energy.columns[0],axis=1)
Energy

# %%
Energy=Energy.drop(Energy.columns[0],axis=1)
Energy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\4013771564.py in <module>
# ----> 1 Energy=Energy.drop(Energy.columns[0],axis=1)
#       2 Energy
#
# NameError: name 'Energy' is not defined

# %%
Energy=Energy.rename(columns={Energy.columns[0]:"Country",Energy.columns[1]:"Energy Supply",Energy.columns[2]:"Energy Supply per Capita",Energy.columns[3]:"% Renewable"})
Energy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\914471800.py in <module>
# ----> 1 Energy=Energy.rename(columns={Energy.columns[0]:"Country",Energy.columns[1]:"Energy Supply",Energy.columns[2]:"Energy Supply per Capita",Energy.columns[3]:"% Renewable"})
#       2 Energy
#
# NameError: name 'Energy' is not defined

# %%
Energy["Energy Supply"]=Energy["Energy Supply"]*1000000
Energy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\3109878268.py in <module>
# ----> 1 Energy["Energy Supply"]=Energy["Energy Supply"]*1000000
#       2 Energy
#
# NameError: name 'Energy' is not defined

# %%
import numpy as np
Energy=Energy.replace('...',np.NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\1710182866.py in <module>
#       1 import numpy as np
# ----> 2 Energy=Energy.replace('...',np.NaN)
#
# NameError: name 'Energy' is not defined

# %%
Energy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\2884162844.py in <module>
# ----> 1 Energy
#
# NameError: name 'Energy' is not defined

# %%
for i in range(18,245,1): 
        if Energy["Country"][i]=="Republic of Korea":
            Energy["Country"][i]="South Korea"
        elif(Energy["Country"][i]=="United States of America"):
             Energy["Country"][i]="United States"
        elif(Energy["Country"][i]=="United Kingdom of Great Britain and Northern Ireland"):
             Energy["Country"][i]="United Kingdom"
        elif(Energy["Country"][i]=="China, Hong Kong Special Administrative Region"):
             Energy["Country"][i]="Hong Kong"
        else:
             continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\1923523757.py in <module>
#       1 for i in range(18,245,1):
# ----> 2         if Energy["Country"][i]=="Republic of Korea":
#       3             Energy["Country"][i]="South Korea"
#       4         elif(Energy["Country"][i]=="United States of America"):
#       5              Energy["Country"][i]="United States"
#
# NameError: name 'Energy' is not defined

# %%
Energy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\2884162844.py in <module>
# ----> 1 Energy
#
# NameError: name 'Energy' is not defined

# %%
Energy["Country"][18]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\3476857610.py in <module>
# ----> 1 Energy["Country"][18]
#
# NameError: name 'Energy' is not defined

# %%
for i in range(18,245,1): 
        if Energy["Country"][i]=="Republic of Korea":
            Energy["Country"][i]="South Korea"
        elif(Energy["Country"][i]=="United States of America"):
             Energy["Country"][i]="United States"
        elif(Energy["Country"][i]=="United Kingdom of Great Britain and Northern Ireland19"):
             Energy["Country"][i]="United Kingdom"
        elif(Energy["Country"][i]=="China, Hong Kong Special Administrative Region"):
             Energy["Country"][i]="Hong Kong"
        elif('(' in str(Energy["Country"][i])):
            Energy["Country"][i]=Energy["Country"][i].split('(')[0].strip()
        else:
            continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\1085899976.py in <module>
#       1 for i in range(18,245,1):
# ----> 2         if Energy["Country"][i]=="Republic of Korea":
#       3             Energy["Country"][i]="South Korea"
#       4         elif(Energy["Country"][i]=="United States of America"):
#       5              Energy["Country"][i]="United States"
#
# NameError: name 'Energy' is not defined

# %%
Energy["Country"][238]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\3924967139.py in <module>
# ----> 1 Energy["Country"][238]
#
# NameError: name 'Energy' is not defined

# %%
GDP=pd.read_csv("assets/world_bank.csv")

# %%
GDP=GDP[4:268]

# %%
GDP.columns=['Country','Country Code','Indicator Name','Indicator Code',1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]

# %%
GDP
# Out:
#               Country Country Code                            Indicator Name  \
# 4               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 5             Andorra          AND  GDP at market prices (constant 2010 US$)
# 6         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 7              Angola          AGO  GDP at market prices (constant 2010 US$)
# 8             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 263       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 264      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 265  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 266            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 267          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
# ...

# %%
for i in range(4,268,1):
        if GDP["Country"][i]=="Korea, Rep.":
            GDP["Country"][i]="South Korea"
        elif GDP["Country"][i]=="Iran, Islamic Rep.":
            GDP["Country"][i]="Iran"
        elif GDP["Country"][i]=="China, Hong Kong Special Administrative Region":
            GDP["Country"][i]="Hong Kong"
        else:
            continue
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13880\2503630652.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP["Country"][i]="South Korea"

# %%
ScimEn=pd.read_excel("assets/scimagojr-3.xlsx")
ScimEn.head(10)
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
# 5     6              Canada      17899              17620     215003
# 6     7             Germany      17027              16831     140566
# 7     8               India      15005              14841     128763
# 8     9              France      13153              12973     130632
# 9    10         South Korea      11983              11923     114675
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# ...

# %%
Energy.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\2224392688.py in <module>
# ----> 1 Energy.head()
#
# NameError: name 'Energy' is not defined

# %%
GDP.iloc[123]

# %%
GDP=GDP[['Country','Country Code','Indicator Name','Indicator Code',2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]]

# %%
GDP

# %%
mergedDataFrame=pd.merge(Energy,GDP,how="outer",on="Country")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\2682423795.py in <module>
# ----> 1 mergedDataFrame=pd.merge(Energy,GDP,how="outer",on="Country")
#
# NameError: name 'Energy' is not defined

# %%
mergedDataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\3908487057.py in <module>
# ----> 1 mergedDataFrame
#
# NameError: name 'mergedDataFrame' is not defined

# %%
#For opening an excel file we use the following syntax.
Energy=pd.read_excel("assets/Energy Indicators.xls")
Energy=Energy[18:245]
#Now above code is a step to actually remove the header and footer of excel sheets. See into real excel file that main data
#begins at 18 and ends at row 245.
    
#Lets now delete unwanted columns
Energy=Energy.drop(Energy.columns[0],axis=1)
Energy=Energy.drop(Energy.columns[0],axis=1)
#U might be seeing a completely different approach here. Well Note that we use this when we delete columns by index rather 
#than thier names.
    
#Let now rename our columns
Energy=Energy.rename(columns={Energy.columns[0]:"Country",Energy.columns[1]:"Energy Supply",Energy.columns[2]:"Energy Supply per Capita",Energy.columns[3]:"% Renewable"})
    
#Lets convert all the Energy Supply Available in Petajoules to Gigajoules
Energy["Energy Supply"]=Energy["Energy Supply"]*1000000
    
#Lets replace ... with np.NaN
Energy=Energy.replace('...',np.NaN)
    
#Renameing rows.
for i in range(18,245,1): 
    if Energy["Country"][i]=="Republic of Korea":
        Energy["Country"][i]="South Korea"
    elif(Energy["Country"][i]=="United States of America20"):
        Energy["Country"][i]="United States"
    elif(Energy["Country"][i]=="United Kingdom of Great Britain and Northern Ireland19"):
        Energy["Country"][i]="United Kingdom"
    elif(Energy["Country"][i]=="China, Hong Kong Special Administrative Region3"):
        Energy["Country"][i]="Hong Kong"
    elif(Energy["Country"][i]=="Japan10"):
            Energy["Country"][i]="Japan"
    elif(Energy["Country"][i]=="China2"):
        Energy["Country"][i]="China"
    elif(Energy["Country"][i]=="France6"):
        Energy["Country"][i]="France"
    elif(Energy["Country"][i]=="Italy9"):
        Energy["Country"][i]="Italy"
    elif(Energy["Country"][i]=="Spain16"):
        Energy["Country"][i]="Spain"
    elif(Energy["Country"][i]=="Australia1"):
        Energy["Country"][i]="Australia"
    elif('(' in str(Energy["Country"][i])):
        Energy["Country"][i]=str(Energy["Country"][i]).split('(')[0].strip()
    else:
        continue
    
import pandas as pd
    #Importing new datafile GDP
GDP=pd.read_csv("assets/world_bank.csv")
    
#lets cut out the important sections of our datafile
GDP=GDP[4:268]
    
#lets set the column headers for the dataframe
GDP.columns=['Country','Country Code','Indicator Name','Indicator Code',1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
    
#Lets rename some of the elements under the Country Column
for i in range(4,268,1):
    if GDP["Country"][i]=="Korea, Rep.":
        GDP["Country"][i]="South Korea"
    elif GDP["Country"][i]=="Iran, Islamic Rep.":
        GDP["Country"][i]="Iran"
    elif GDP["Country"][i]=="China, Hong Kong Special Administrative Region":
        GDP["Country"][i]="Hong Kong"
    else:
        continue
        
GDP=GDP[['Country','Country Code','Indicator Name','Indicator Code',2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]]
            
#Let import another data file
ScimEn=pd.read_excel("assets/scimagojr-3.xlsx")
ScimEn=ScimEn[0:15]
    
#Lets merge the 3 dataframes
mergedDataFrame=pd.merge(ScimEn,GDP,how="inner",on="Country")
remergedDat=pd.merge(mergedDataFrame,Energy,how="inner",on="Country").set_index("Country")
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13880\1897905619.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Australia"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13880\1897905619.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]=str(Energy["Country"][i]).split('(')[0].strip()
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13880\1897905619.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
remergedDat[['Rank','Documents','Citable documents','Citations','Self-citations','Citations per document','H index','Energy Supply','Energy Supply per Capita','% Renewable',2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]]
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
remergedDat=remergedDat.drop(remergedDat.columns[7],axis=1)

# %%
remergedDat=remergedDat.drop(remergedDat.columns[7],axis=1)

# %%
remergedDat=remergedDat.drop(remergedDat.columns[7],axis=1)

# %%
remergedDat
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
remergedDat=remergedDat.sort_values("Rank",ascending=True)

# %%
remergedDat
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
np.mean(remergedDat[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]])
# Out:
# C:\Users\ashut\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 2006    2.978152e+12
# 2007    3.095871e+12
# 2008    3.141171e+12
# 2009    3.085834e+12
# 2010    3.219173e+12
# 2011    3.313404e+12
# 2012    3.391038e+12
# 2013    3.470126e+12
# 2014    3.562304e+12
# 2015    3.875826e+12
# dtype: float64

# %%
np.mean(remergedDat[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]])
# Out:
# C:\Users\ashut\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 2006    2.978152e+12
# 2007    3.095871e+12
# 2008    3.141171e+12
# 2009    3.085834e+12
# 2010    3.219173e+12
# 2011    3.313404e+12
# 2012    3.391038e+12
# 2013    3.470126e+12
# 2014    3.562304e+12
# 2015    3.875826e+12
# dtype: float64

# %%
np.mean(remergedDat.loc[["India","Iran"],[2006,2007]])
# Out:
# C:\Users\ashut\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 2006    8.277233e+11
# 2007    8.999649e+11
# dtype: float64

# %%
remergedDat[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]].mean(axis=1)
# Out:
# Country
# China                 6.348609e+12
# United States         1.536434e+13
# Japan                 5.542208e+12
# United Kingdom        2.487907e+12
# Russian Federation    1.565459e+12
# Canada                1.660647e+12
# Germany               3.493025e+12
# India                 1.769297e+12
# France                2.681725e+12
# South Korea           1.106715e+12
# Italy                 2.120175e+12
# Spain                 1.418078e+12
# Iran                  4.441558e+11
# Australia             1.164043e+12
# Brazil                2.189794e+12
# dtype: float64

# %%
Series=np.mean(remergedDat[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]],axis=1)

# %%
Series
# Out:
# Country
# China                 6.348609e+12
# United States         1.536434e+13
# Japan                 5.542208e+12
# United Kingdom        2.487907e+12
# Russian Federation    1.565459e+12
# Canada                1.660647e+12
# Germany               3.493025e+12
# India                 1.769297e+12
# France                2.681725e+12
# South Korea           1.106715e+12
# Italy                 2.120175e+12
# Spain                 1.418078e+12
# Iran                  4.441558e+11
# Australia             1.164043e+12
# Brazil                2.189794e+12
# dtype: float64

# %%
dataframe=remergedDat
series=Series
series=series.sort_values(ascending=False)
country=series.index[5]

# %%
changeInGDP=dataframe.loc[country][2015]-dataframe.loc[country][2006]
changeInGDP
# Out:
# 246702696075.3999

# %%
np.mean(remergedDat["Energy Supply per Capita"])
# Out:
# 157.6

# %%
remergedDat["Energy Supply per Capita"].mean()
# Out:
# 157.6

# %%
np.max(remergedDat["% Renewable"])
# Out:
# 69.64803

# %%
rearrange=remergedDat.sort_values("% Renewable",ascending=False)

# %%
rearrange.index[0]
# Out:
# 'Brazil'

# %%
remergedDat["Ratio"]=remergedDat["Self-citations"]/remergedDat["Citable documents"]
remergedDat
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
requiredDat=remergedDat

# %%
requiredDat
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
requiredDat["Population"]=requiredDat["Energy Supply"]/requiredDat["Energy Supply per Capita"]
requiredDat["DocsPerPerson"]=requiredDat["Citable documents"]/requiredDat["Population"]
print(requiredDat["DocsPerPerson"].corr(requiredDat["Energy Supply per Capita"]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13880\2738456829.py in <module>
#       1 requiredDat["Population"]=requiredDat["Energy Supply"]/requiredDat["Energy Supply per Capita"]
#       2 requiredDat["DocsPerPerson"]=requiredDat["Citable documents"]/requiredDat["Population"]
# ----> 3 print(requiredDat["DocsPerPerson"].corr(requiredDat["Energy Supply per Capita"]))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2555
#    2556         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2557             return nanops.nancorr(
#    2558                 this.values, other.values, method=method, min_periods=min_periods
#    2559             )
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
# ...

# %%
requiredDat
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
requiredDat["% Renewable"].median()
# Out:
# 17.02028

# %%
requiredDat["% Renewable"][0]
# Out:
# 19.75491

# %%
requiredDat
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
requiredDat["HighRenew"]=requiredDat["Rank"]
average=requiredDat["% Renewable"].median()
for i in range(0,15,1):
    if requiredDat["% Renewable"][i]>=average:
        requiredDat['HighRenew'][i]=1
    else:
        requiredDat['HighRenew'][i]=0
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13880\2557178755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   requiredDat['HighRenew'][i]=1
# C:\Users\ashut\AppData\Local\Temp\ipykernel_13880\2557178755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   requiredDat['HighRenew'][i]=0

# %%
requiredDat
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...
