# %%
import pandas as pd
import numpy as np

# %%
def answer_one():
    #For opening an excel file we use the following syntax.
    Energy=pd.read_excel("assets/Energy Indicators.xls")
    Energy=Energy[18:245]
    #Now abaove code is a step to actually remove the header and footer of excel sheets. See into real excel file that main data
    #begins at 18 and ends at row 245.
    
    #Lets now delete unwanted columns
    Energy=Energy.drop(Energy.columns[0],axis=1)
    Energy=Energy.drop(Energy.columns[0],axis=1)
    #U might be seeing a completely different approach here. Well Note that we use this when we delete columns by index rather 
    #than thier names.
    
    #Let now rename our columns
    Energy=Energy.rename(columns={Energy.columns[0]:"Country",Energy.columns[1]:"Energy Supply",Energy.columns[2]:"Energy Supply per Capita",Energy.columns[3]:"% Renewable"})
    
    #Lets convert all the Energy Supply Available in Petajoules to Gigajoules
    Energy["Energy Supply"]=Energy["Energy Supply"]*1000000
    
    #Lets replace ... with np.NaN
    Energy=Energy.replace('...',np.NaN)
    
    #Renameing rows.
    for i in range(18,245,1): 
        if Energy["Country"][i]=="Republic of Korea":
            Energy["Country"][i]="South Korea"
        elif(Energy["Country"][i]=="United States of America20"):
             Energy["Country"][i]="United States"
        elif(Energy["Country"][i]=="United Kingdom of Great Britain and Northern Ireland19"):
             Energy["Country"][i]="United Kingdom"
        elif(Energy["Country"][i]=="China, Hong Kong Special Administrative Region3"):
             Energy["Country"][i]="Hong Kong"
        elif(Energy["Country"][i]=="Japan10"):
            Energy["Country"][i]="Japan"
        elif(Energy["Country"][i]=="China2"):
            Energy["Country"][i]="China"
        elif(Energy["Country"][i]=="France6"):
            Energy["Country"][i]="France"
        elif(Energy["Country"][i]=="Italy9"):
            Energy["Country"][i]="Italy"
        elif(Energy["Country"][i]=="Spain16"):
            Energy["Country"][i]="Spain"
        elif(Energy["Country"][i]=="Australia1"):
            Energy["Country"][i]="Australia"
        elif('(' in str(Energy["Country"][i])):
            Energy["Country"][i]=Energy["Country"][i].split('(')[0].strip()
        else:
            continue
    
    #Importing new datafile GDP
    GDP=pd.read_csv("assets/world_bank.csv")
    
    #lets cut out the important sections of our datafile
    GDP=GDP[4:268]
    
    #lets set the column headers for the dataframe
    GDP.columns=['Country','Country Code','Indicator Name','Indicator Code',1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
    
    #Lets rename some of the elements under the Country Column
    for i in range(4,268,1):
        if GDP["Country"][i]=="Korea, Rep.":
            GDP["Country"][i]="South Korea"
        elif GDP["Country"][i]=="Iran, Islamic Rep.":
            GDP["Country"][i]="Iran"
        elif GDP["Country"][i]=="China, Hong Kong Special Administrative Region":
            GDP["Country"][i]="Hong Kong"
        else:
            continue
    GDP=GDP[['Country','Country Code','Indicator Name','Indicator Code',2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]]
            
    #Let import another data file
    ScimEn=pd.read_excel("assets/scimagojr-3.xlsx")
    ScimEn=ScimEn[0:15]
    
    #Lets merge the 3 dataframes
    mergedDataFrame=pd.merge(ScimEn,GDP,how="inner",on="Country")
    remergedDat=pd.merge(mergedDataFrame,Energy,how="inner",on="Country").set_index("Country")
    remergedDat=remergedDat.drop(remergedDat.columns[7],axis=1)
    remergedDat=remergedDat.drop(remergedDat.columns[7],axis=1)
    remergedDat=remergedDat.drop(remergedDat.columns[7],axis=1)
    remergedDat=remergedDat.sort_values("Rank",ascending=True)
    return(remergedDat)
    raise NotImplementedError()

# %%
dataframe=answer_one()
dataframe
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Australia"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]=Energy["Country"][i].split('(')[0].strip()
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="China"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Hong Kong"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="France"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Italy"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Japan"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="South Korea"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Spain"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="United Kingdom"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="United States"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP["Country"][i]="South Korea"
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# Australia             14       8831               8725      90765
# Brazil                15       8668               8596      60702
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57
# Canada                       40930                   12.01      149
# Germany                      27426                    8.26      126
# India                        37209                    8.58      115
# France                       28601                    9.93      114
# South Korea                  22595                    9.57      104
# Italy                        26661                   10.20      106
# Spain                        23964                   13.08      115
# Iran                         19125                    6.46       72
# Australia                    15606                   10.28      107
# Brazil                       14396                    7.00       86
#
#                             2006          2007          2008          2009  \
# Country
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# United States       1.479230e+13  1.505540e+13  1.501149e+13  1.459484e+13
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# United Kingdom      2.419631e+12  2.482203e+12  2.470614e+12  2.367048e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# France              2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Spain               1.414823e+12  1.468146e+12  1.484530e+12  1.431475e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# Australia           1.021939e+12  1.060340e+12  1.099644e+12  1.119654e+12
# Brazil              1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
#
#                             2010          2011          2012          2013  \
# Country
# China               6.039659e+12  6.612490e+12  7.124978e+12  7.672448e+12
# United States       1.496437e+13  1.520402e+13  1.554216e+13  1.577367e+13
# Japan               5.498718e+12  5.473738e+12  5.569102e+12  5.644659e+12
# United Kingdom      2.403504e+12  2.450911e+12  2.479809e+12  2.533370e+12
# Russian Federation  1.524917e+12  1.589943e+12  1.645876e+12  1.666934e+12
# Canada              1.613406e+12  1.664087e+12  1.693133e+12  1.730688e+12
# Germany             3.417298e+12  3.542371e+12  3.556724e+12  3.567317e+12
# India               1.708459e+12  1.821872e+12  1.924235e+12  2.051982e+12
# France              2.646995e+12  2.702032e+12  2.706968e+12  2.722567e+12
# South Korea         1.094499e+12  1.134796e+12  1.160809e+12  1.194429e+12
# Italy               2.125185e+12  2.137439e+12  2.077184e+12  2.040871e+12
# Spain               1.431673e+12  1.417355e+12  1.380216e+12  1.357139e+12
# Iran                4.677902e+11  4.853309e+11  4.532569e+11  4.445926e+11
# Australia           1.142251e+12  1.169431e+12  1.211913e+12  1.241484e+12
# Brazil              2.208872e+12  2.295245e+12  2.339209e+12  2.409740e+12
#
#                             2014          2015 Energy Supply  \
# Country
# China               8.230121e+12  8.797999e+12  127191000000
# United States       1.615662e+13  1.654857e+13   90838000000
# Japan               5.642884e+12  5.669563e+12   18984000000
# United Kingdom      2.605643e+12  2.666333e+12    7920000000
# Russian Federation  1.678709e+12  1.616149e+12   30709000000
# Canada              1.773486e+12  1.792609e+12   10431000000
# Germany             3.624386e+12  3.685556e+12   13261000000
# India               2.200617e+12  2.367206e+12   33195000000
# France              2.729632e+12  2.761185e+12   10597000000
# South Korea         1.234340e+12  1.266580e+12   11007000000
# Italy               2.033868e+12  2.049316e+12    6530000000
# Spain               1.375605e+12  1.419821e+12    4923000000
# Iran                4.639027e+11           NaN    9172000000
# Australia           1.272520e+12  1.301251e+12    5386000000
# Brazil              2.412231e+12  2.319423e+12   12149000000
#
#                     Energy Supply per Capita  % Renewable
# Country
# China                                   93.0    19.754910
# United States                          286.0    11.570980
# Japan                                  149.0    10.232820
# United Kingdom                         124.0    10.600470
# Russian Federation                     214.0    17.288680
# Canada                                 296.0    61.945430
# Germany                                165.0    17.901530
# India                                   26.0    14.969080
# France                                 166.0    17.020280
# South Korea                            221.0     2.279353
# Italy                                  109.0    33.667230
# Spain                                  106.0    37.968590
# Iran                                   119.0     5.707721
# Australia                              231.0    11.810810
# Brazil                                  59.0    69.648030

# %%
remergedDat=answer_one()
avgGDP=np.mean(remergedDat[[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]],axis=1)
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Australia"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]=Energy["Country"][i].split('(')[0].strip()
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="China"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Hong Kong"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="France"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Italy"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Japan"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="South Korea"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Spain"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="United Kingdom"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="United States"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\3203402049.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP["Country"][i]="South Korea"

# %%
avgGDP.sort_values(ascending=False)
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
def answer_two():
    #Preparing Set1
    Energy=pd.read_excel("assets/Energy Indicators.xls")
    Energy=Energy[18:245]
    Energy=Energy.drop(Energy.columns[0],axis=1)
    Energy=Energy.drop(Energy.columns[0],axis=1)
    Energy=Energy.rename(columns={Energy.columns[0]:"Country",Energy.columns[1]:"Energy Supply",Energy.columns[2]:"Energy Supply per Capita",Energy.columns[3]:"% Renewable"})
    Energy["Energy Supply"]=Energy["Energy Supply"]*1000000
    Energy=Energy.replace('...',np.NaN)
    for i in range(18,245,1): 
        if Energy["Country"][i]=="Republic of Korea":
            Energy["Country"][i]="South Korea"
        elif(Energy["Country"][i]=="United States of America20"):
             Energy["Country"][i]="United States"
        elif(Energy["Country"][i]=="United Kingdom of Great Britain and Northern Ireland19"):
             Energy["Country"][i]="United Kingdom"
        elif(Energy["Country"][i]=="China, Hong Kong Special Administrative Region3"):
             Energy["Country"][i]="Hong Kong"
        elif(Energy["Country"][i]=="Japan10"):
            Energy["Country"][i]="Japan"
        elif(Energy["Country"][i]=="China2"):
            Energy["Country"][i]="China"
        elif(Energy["Country"][i]=="France6"):
            Energy["Country"][i]="France"
        elif(Energy["Country"][i]=="Italy9"):
            Energy["Country"][i]="Italy"
        elif(Energy["Country"][i]=="Spain16"):
            Energy["Country"][i]="Spain"
        elif(Energy["Country"][i]=="Australia1"):
            Energy["Country"][i]="Australia"
        elif('(' in str(Energy["Country"][i])):
            Energy["Country"][i]=Energy["Country"][i].split('(')[0].strip()
        else:
            continue
    
    #Preparing Set2
    GDP=pd.read_csv("assets/world_bank.csv")
    GDP=GDP[4:268]
    GDP.columns=['Country','Country Code','Indicator Name','Indicator Code',1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
    for i in range(4,268,1):
        if GDP["Country"][i]=="Korea, Rep.":
            GDP["Country"][i]="South Korea"
        elif GDP["Country"][i]=="Iran, Islamic Rep.":
            GDP["Country"][i]="Iran"
        elif GDP["Country"][i]=="China, Hong Kong Special Administrative Region":
            GDP["Country"][i]="Hong Kong"
        else:
            continue
    
    #Preparing Set3
    ScimEn=pd.read_excel("assets/scimagojr-3.xlsx")
    
    #Our next step is to find total possible elements. Wr are going to this via taking the union of the 3 dataframes.
    union1=pd.merge(ScimEn,GDP,how="outer",on="Country")
    union2=pd.merge(union1,Energy,how="outer",on="Country")
    LenTotalElements=len(union2)
    
    #Lets find intersection of the 3 datasets.
    mergedDataFrame=pd.merge(ScimEn,GDP,how="inner",on="Country")
    remergedDat=pd.merge(mergedDataFrame,Energy,how="inner",on="Country")
    LenIntersectionElements=len(remergedDat)
    
    #Then Number of value lost
    entriesLost=LenTotalElements-LenIntersectionElements
    
    return(entriesLost)
    raise NotImplementedError()

# %%
answer_two()
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Australia"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]=Energy["Country"][i].split('(')[0].strip()
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="China"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Hong Kong"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="France"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Italy"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Japan"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="South Korea"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="Spain"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="United Kingdom"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Energy["Country"][i]="United States"
# C:\Users\ashut\AppData\Local\Temp\ipykernel_22924\2670640270.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP["Country"][i]="South Korea"
# 182
